# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 37 not upgraded.
# Need to get 9,604 kB of archives.
# After this operation, 29.5 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 fonts-nanum all 20170925-1 [9,604 kB]
# Fetched 9,604 kB in 1s (7,297 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 155013 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20170925-1_all.deb ...
# Unpacking fonts-nanum (20170925-1) ...
# Setting up fonts-nanum (20170925-1) ...
# Processing triggers for fontconfig (2.12.6-0ubuntu2) ...
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 10 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %%
import pandas as pd
df1 = pd.read_csv('/content/drive/MyDrive/zzang9.csv')

df1
# Out:
#      Unnamed: 0  ...                                            content
# 0             0  ...  ['\u200b🔈해당게시판은 생방송 컨텐츠에 사용 될 수 있습니다. 데일리룩 관련 ...
# 1             1  ...  ['\u200b🔈해당게시판은 생방송 컨텐츠에 사용 될 수 있습니다. 데일리룩 관련 ...
# 2             2  ...  ['\u200b🔈해당게시판은 생방송 컨텐츠에 사용 될 수 있습니다. 데일리룩 관련 ...
# 3             3  ...  ["▷ 짱구대디랑 카페 체험단은 브랜드로부터 진행 비용 및 제품을 제공 받아 진행하...
# 4             4  ...  ['▷ 짱구대디랑 카페 체험단은 브랜드로부터 진행 비용 및 제품을 제공 받아 진행하...
# ..          ...  ...                                                ...
# 411         411  ...  ['※글 작성시 위 배너를 삭제하시면 활동 제제 & 글 무통보 삭제 대상이오니 유의...
# 412         412  ...  ['※글 작성시 위 배너를 삭제하시면 활동 제제 & 글 무통보 삭제 대상이오니 유의...
# 413         413  ...  ['※글 작성시 위 배너를 삭제하시면 활동 제제 & 글 무통보 삭제 대상이오니 유의...
# 414         414  ...  ['※글 작성시 위 배너를 삭제하시면 활동 제제 & 글 무통보 삭제 대상이오니 유의...
# 415         415  ...  ['※글 작성시 위 배너를 삭제하시면 활동 제제 & 글 무통보 삭제 대상이오니 유의...
#
# [416 rows x 3 columns]

# %%
# !pip install konlpy wordcloud
# Out:
# Requirement already satisfied: konlpy in /usr/local/lib/python3.7/dist-packages (0.5.2)
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.7/dist-packages (1.5.0)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.7/dist-packages (from konlpy) (1.19.5)
# Requirement already satisfied: tweepy>=3.7.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (3.10.0)
# Requirement already satisfied: beautifulsoup4==4.6.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (4.6.0)
# Requirement already satisfied: colorama in /usr/local/lib/python3.7/dist-packages (from konlpy) (0.4.4)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (4.2.6)
# Requirement already satisfied: JPype1>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (1.3.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from JPype1>=0.7.0->konlpy) (3.7.4.3)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (1.15.0)
# Requirement already satisfied: requests[socks]>=2.11.1 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (2.23.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (1.3.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->tweepy>=3.7.0->konlpy) (3.1.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2021.5.30)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2.10)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.7.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from wordcloud) (7.1.2)

# %%
from konlpy.tag import Okt
from collections import Counter

# %%
new_data = pd.DataFrame(df1, columns = ['title', 'content'])

# %%
new_data
# Out:
#                            title                                            content
# 0                      여름과 가을 사이  ['\u200b🔈해당게시판은 생방송 컨텐츠에 사용 될 수 있습니다. 데일리룩 관련 ...
# 1                    푸마 유아인 자켓 🐆  ['\u200b🔈해당게시판은 생방송 컨텐츠에 사용 될 수 있습니다. 데일리룩 관련 ...
# 2                       요즘 날씨에 딱  ['\u200b🔈해당게시판은 생방송 컨텐츠에 사용 될 수 있습니다. 데일리룩 관련 ...
# 3        [클락스] 클락스 데저트 트랙 체험단 후기  ["▷ 짱구대디랑 카페 체험단은 브랜드로부터 진행 비용 및 제품을 제공 받아 진행하...
# 4    [9월] 와르 21FW 데님 컬렉션 체험단 모집!  ['▷ 짱구대디랑 카페 체험단은 브랜드로부터 진행 비용 및 제품을 제공 받아 진행하...
# ..                           ...                                                ...
# 411     트렌치코트 복원 수선 가능한 곳 아시나요??  ['※글 작성시 위 배너를 삭제하시면 활동 제제 & 글 무통보 삭제 대상이오니 유의...
# 412                      핏 괜찮나요?  ['※글 작성시 위 배너를 삭제하시면 활동 제제 & 글 무통보 삭제 대상이오니 유의...
# 413            신발포인트 코디(조셉트 내추럴)  ['※글 작성시 위 배너를 삭제하시면 활동 제제 & 글 무통보 삭제 대상이오니 유의...
# 414                      캠퍼스 근본룩  ['※글 작성시 위 배너를 삭제하시면 활동 제제 & 글 무통보 삭제 대상이오니 유의...
# 415                      봄봄하게 입기  ['※글 작성시 위 배너를 삭제하시면 활동 제제 & 글 무통보 삭제 대상이오니 유의...
#
# [416 rows x 2 columns]

# %%
text_data = []
nlp = Okt()

for i in range(len(new_data.index)):
    for j in range(len(new_data.columns)):
        row_text = nlp.nouns(new_data.iloc[i, j])
        for m in range(len(row_text)):
            if len(row_text[m])>=2:
                text_data.append(row_text[m])

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

stop_words = "모든 게시 사진 첨부 질문 삭제 활동 정지 보기 생각 필수 구매 카페 제품 작성 배너 제재 통보 대상 유의 게시판 공지 관련 일리 혹시"

result = []
for w in text_data:
    if w not in stop_words:
        result.append(w)

# %%
for i in range(len(result)):
    if result[i] == '빈티':
        result[i] = '빈티지'

result
# Out:
# ['여름',
#  '가을',
#  '사이',
#  '해당',
#  '생방송',
#  '컨텐츠',
#  '사용',
#  '가을',
#  '여름',
#  '느낌',
#  '셔츠',
#  '살짝',
#  '기본',
#  '양식',
#  '아우',
#  '상의',
#  '구제',
#  '폴로',
#  '자바',
#  '나스',
#  '오리',
#  '가먼츠',
#  '신발',
#  '뉴발',
#  '기타',
#  '하트',
#  '팩키',
#  '몸무게',
#  '선택',
#  '푸마',
#  '유아인',
#  '자켓',
#  '해당',
#  '생방송',
#  '컨텐츠',
#  '사용',
#  '기본',
#  '양식',
#  '아우',
#  '푸마',
#  '상의',
#  '예스',
#  '이씨',
#  '피스',
#  '워커',
#  '신발',
#  '기타',
#  '몸무게',
#  '선택',
#  '요런',
#  '자켓',
#  '구제',
#  '느낌',
#  '요즘',
#  '날씨',
#  '해당',
#  '생방송',
#  '컨텐츠',
#  '사용',
#  '체험',
#  '기용',
#  '요즘',
#  '날씨',
#  '코디',
#  '기본',
#  '양식',
#  '아우',
#  '상의',
#  '폴로',
#  '구제',
#  '자바',
#  '나스',
#  '무탠',
#  '다드',
#  '신발',
#  '락스',
#  '데저트',
#  '트랙',
#  '체험',
#  '기타',
#  '드로우핏키',
#  '몸무게',
#  '선택',
#  '락스',
#  '락스',
#  '데저트',
#  '트랙',
#  '체험',
#  '후기',
#  '대디',
#  '체험',
#  '브랜드',
#  '로부터',
#  '진행',
#  '비용',
#  '제공',
#  '진행',
#  '이벤',
#  '링크',
#  '락스',
#  '데저트',
#  '트랙',
#  '락스',
#  '가을',
#  '단풍',
#  '헤리티지',
#  '브랜드',
#  '폴더',
#  '공식',
#  '온라인',
#  '스토어',
#  '구승',
#  '이번',
#  '체험',
#  '청단',
#  '드로우핏',
#  '데님',
#  '자켓',
#  '락스',
#  '체험',
#  '당첨',
#  '체험',
#  '후기',
#  '락스',
#  '데저트',
#  '트랙',
#  '현재',
#  '락스',
#  '폴더',
#  '최대',
#  '할인',
#  '중이',
#  '고제',
#  '데저트',
#  '트랙',
#  '최대',
#  '할인',
#  '디테',
#  '착샷',
#  '락스',
#  '박스',
#  '블랙',
#  '색상',
#  '브랜드',
#  '심플',
#  '포장',
#  '상태',
#  '여분',
#  '나중',
#  '교체',
#  '신어',
#  '이름',
#  '데저트',
#  '트랙',
#  '사막',
#  '트랙',
#  '사람',
#  '그림',
#  '코디',
#  '조금',
#  '가죽',
#  '락스',
#  '특징',
#  '하나',
#  '밑창',
#  '처음',
#  '조금',
#  '당황',
#  '무드',
#  '디자인',
#  '오염',
#  '모도',
#  '보강',
#  '착용',
#  '실루엣',
#  '사실',
#  '왈라비',
#  '지망',
#  '데저트',
#  '트랙',
#  '살짝',
#  '당황',
#  '신발',
#  '둥그런',
#  '다른',
#  '매력',
#  '코디',
#  '포인트',
#  '사이즈',
#  '정사',
#  '이즈',
#  '사이즈',
#  '뉴발',
#  '신발',
#  '꽉끈',
#  '트랙',
#  '다운',
#  '정도',
#  '체험',
#  '사이즈',
#  '정사',
#  '이즈',
#  '크게',
#  '신발',
#  '조금',
#  '느낌',
#  '최대한',
#  '조여',
#  '발볼',
#  '신분',
#  '사이즈',
#  '다운',
#  '추천',
#  '상의',
#  '미니',
#  '프로젝트',
#  '자바',
#  '나스',
#  '제로',
#  '신발',
#  '락스',
#  '데저트',
#  '트랙',
#  '몸무게',
#  '후리',
#  '후드',
#  '집업',
#  '스웻팬츠',
#  '셋업',
#  '코디',
#  '그냥',
#  '느낌',
#  '신발',
#  '디자인',
#  '주얼',
#  '느낌',
#  '신발',
#  '클로즈업',
#  '상의',
#  '구제',
#  '폴로',
#  '자바',
#  '나스',
#  '무탠',
#  '다드',
#  '신발',
#  '락스',
#  '데저트',
#  '트랙',
#  '가방',
#  '드로우핏키',
#  '몸무게',
#  '두번째',
#  '코디',
#  '느낌',
#  '코디',
#  '스티',
#  '베이지',
#  '슬랙스',
#  '달라',
#  '조금',
#  '코디',
#  '무드',
#  '색상',
#  '대해',
#  '말씀',
#  '스티',
#  '베이지',
#  '슬랙스',
#  '브라운',
#  '트랙',
#  '색상',
#  '좀더',
#  '느낌',
#  '신발',
#  '대한',
#  '평소',
#  '스니커즈',
#  '대비',
#  '정사',
#  '커서',
#  '살짝',
#  '느낌',
#  '레이스',
#  '박스',
#  '부분',
#  '꽉끈',
#  '한계',
#  '밑창',
#  '코디',
#  '몇번',
#  '벌써',
#  '시작',
#  '락스',
#  '브랜드',
#  '특징',
#  '느낌',
#  '밑창',
#  '마음',
#  '처음',
#  '데저트',
#  '트랙',
#  '보고',
#  '코디',
#  '주얼',
#  '무드',
#  '신발',
#  '매치',
#  '기존',
#  '가지',
#  '신발',
#  '아주',
#  '다른',
#  '무드',
#  '신발',
#  '락스',
#  '감성',
#  '가지',
#  '지금',
#  '할인',
#  '폴더',
#  '와르',
#  '데님',
#  '컬렉션',
#  '체험',
#  '모집',
#  '대디',
#  '체험',
#  '브랜드',
#  '로부터',
#  '진행',
#  '비용',
#  '제공',
#  '진행',
#  '이벤',
#  '체험',
#  '선발',
#  '예정',
#  '왕성',
#  '사람',
#  '브랜드',
#  '선발',
#  '랜덤',
#  '프로그램',
#  '무작위',
#  '선발',
#  '체험',
#  '연속',
#  '당첨',
#  '회원',
#  '자동',
#  '당첨',
#  '취소',
#  '댓글',
#  '통해',
#  '대한',
#  '체험',
#  '이유',
#  '체험',
#  '주일',
#  '이내',
#  '장점',
#  '단점',
#  '여러분',
#  '사실',
#  '그대로',
#  '착샷',
#  '포함',
#  '리뷰',
#  '이상',
#  '수령',
#  '리뷰',
#  '소장',
#  '체험',
#  '당첨',
#  '이후',
#  '후기',
#  '작성자',
#  '미사',
#  '반납',
#  '가액',
#  '청구',
#  '예정',
#  '체험',
#  '후기',
#  '진행',
#  '진행',
#  '모집',
#  '발표',
#  '표시',
#  '체험',
#  '후기',
#  '월간',
#  '유지',
#  '와르',
#  '데님',
#  '컬렉션',
#  '대디',
#  '체험',
#  '모집',
#  '와르',
#  '약자',
#  '우리',
#  '항상',
#  '우리',
#  '의미',
#  '모토로',
#  '가지',
#  '감각',
#  '감성',
#  '누구',
#  '브랜드',
#  '국내',
#  '자체',
#  '제작',
#  '유통',
#  '과정',
#  '마진',
#  '축소',
#  '나은',
#  '퀄리티',
#  '트렌디',
#  '디자인',
#  '프리미엄',
#  '데님',
#  '브랜드',
#  '체험',
#  '소개',
#  '리뷰',
#  '이유',
#  '와이드',
#  '데님',
#  '팬츠',
#  '라이트',
#  '블루',
#  '지퍼',
#  '사실',
#  '체인',
#  '스티치',
#  '로고',
#  '각인',
#  '리벳',
#  '발등',
#  '여유',
#  '기장',
#  '그레이',
#  '시한',
#  '컬러',
#  '데님',
#  '와이드',
#  '세미',
#  '부츠',
#  '데님',
#  '팬츠',
#  '진청',
#  '지퍼',
#  '사실',
#  '체인',
#  '스티치',
#  '로고',
#  '각인',
#  '리벳',
#  '컬러',
#  '브러쉬',
#  '워싱',
#  '기법',
#  '데님',
#  '세미',
#  '부츠',
#  '슬림',
#  '스트레이트',
#  '데님',
#  '팬츠',
#  '지퍼',
#  '사실',
#  '체인',
#  '스티치',
#  '로고',
#  '각인',
#  '리벳',
#  '여유',
#  '스트레이트',
#  '브러쉬',
#  '워싱',
#  '블랙',
#  '컬러',
#  '완성',
#  '데님',
#  '슬림',
#  '스트레이트',
#  '와이드',
#  '데님',
#  '팬츠',
#  '중청',
#  '지퍼',
#  '사실',
#  '체인',
#  '스티치',
#  '로고',
#  '각인',
#  '리벳',
#  '밀크',
#  '워싱',
#  '사용',
#  '워싱',
#  '깊이',
#  '데님',
#  '데님',
#  '원단',
#  '염료',
#  '담금질',
#  '데님',
#  '컬러',
#  '중량',
#  '사의',
#  '원사',
#  '재직',
#  '터치',
#  '데님',
#  '와이드',
#  '구제',
#  '슬림',
#  '스트레이트',
#  '데님',
#  '팬츠',
#  '중청',
#  '지퍼',
#  '사실',
#  '체인',
#  '스티치',
#  '로고',
#  '각인',
#  '리벳',
#  '스판',
#  '착용',
#  '발등',
#  '위로',
#  '기장',
#  '염료',
#  '보이지',
#  '중청',
#  '데님',
#  '슬림',
#  '스트레이트',
#  '참여',
#  '방법',
#  '회원',
#  '평소',
#  '착용',
#  '무드',
#  '컬러',
#  '사이즈',
#  '댓글',
#  '와이드',
#  '데님',
#  '팬츠',
#  '라이트',
#  '블루',
#  '후기',
#  '마케팅',
#  '콘텐츠',
#  '활용',
#  '스냅',
#  '상세',
#  '페이지',
#  '체험',
#  '발표',
#  '진행',
#  '일정',
#  '모집',
#  '기간',
#  '발표',
#  '배송',
#  '추가',
#  '당첨',
#  '배송',
#  '당첨',
#  '발표',
#  '개별',
#  '이메일',
#  '연락',
#  '업체',
#  '당첨',
#  '댓글',
#  '발송',
#  '랜덤',
#  '당첨',
#  '업체',
#  '임의',
#  '물품',
#  '발송',
#  '예정',
#  '진행',
#  '체험',
#  '후기',
#  '진행',
#  '체험',
#  '후기',
#  '후기',
#  '브랜드',
#  '활용',
#  '브랜드',
#  '노출',
#  '체험',
#  '당첨',
#  '문의',
#  '문의',
#  '체험',
#  '진행',
#  '광고',
#  '문의',
#  '데님',
#  '패션',
#  '이용',
#  '의무',
#  '링크',
#  '사람',
#  '데님',
#  '어디',
#  '오프라인',
#  '매장',
#  '지역',
#  '가요',
#  '실제',
#  '데님',
#  '본적',
#  '실제',
#  '핏들',
#  '바지',
#  '소파',
#  '매력',
#  '가죽',
#  '자켓',
#  '해당',
#  '생방송',
#  '컨텐츠',
#  '사용',
#  '기본',
#  '양식',
#  '아우',
#  '구제',
#  '상의',
#  '하의',
#  '신발',
#  '덩크',
#  '기타',
#  '몸무게',
#  '선택',
#  '제리',
#  '동영상',
#  '팔로워',
#  '팔로잉',
#  '제리',
#  '동영상',
#  '쿠어',
#  '블루',
#  '쇼핑',
#  '후기',
#  '실사',
#  '사용',
#  '후기',
#  '누락',
#  '경우',
#  '참고',
#  '기본',
#  '양식',
#  '브랜드',
#  '품명',
#  '쿠어',
#  '블루',
#  '모카',
#  '그레이',
#  '실사',
#  '매번',
#  '블루',
#  '종은',
#  '구제',
#  '아이템',
#  '입다',
#  '이번',
#  '돈좀',
#  '쿠어',
#  '블루',
#  '감성',
#  '역시',
#  '사이즈',
#  '소매',
#  '조금',
#  '기장',
#  '크롭',
#  '여러분',
#  '그냥',
#  '가요',
#  '주말',
#  '홍대',
#  '구제',
#  '쇼핑',
#  '쇼핑',
#  '후기',
#  '실사',
#  '사용',
#  '후기',
#  '누락',
#  '경우',
#  '참고',
#  '기본',
#  '양식',
#  '브랜드',
#  '품명',
#  '구제',
#  '실사',
#  '네이비',
#  '폴로',
#  '니트',
#  '베스트',
#  '그레이',
#  '스트라이프',
#  '블루',
#  '이번',
#  '주말',
#  '홍대',
#  '구제',
#  '빈티지',
#  '가을',
#  '쇼핑',
#  '평소',
#  '구제',
#  '블루',
#  '뭔가',
#  '이번',
#  '패턴',
#  '그레이',
#  '베이지',
#  '와이드',
#  '슬랙스',
#  '시장',
#  '버버리',
#  '정품',
#  '코트',
#  '버버리',
#  '정품',
#  '셔츠',
#  '가격',
#  '호갱',
#  '패션',
#  '이용',
#  '의무',
#  '우선',
#  '시장',
#  '한번',
#  '사람',
#  '기회',
#  '버버리',
#  '정말',
#  '명품',
#  '브랜드',
#  '버버리',
#  '압도',
#  '버버리',
#  '한번',
#  '득템',
#  '한번',
#  '발품',
#  '마음',
#  '구입',
#  '코트',
#  '제시',
#  '처음',
#  '해도',
#  '사람',
#  '구제',
#  '시장',
#  '평균',
#  '가격',
#  '셔츠',
#  '다처',
#  '코트',
#  '호구',
#  '취급',
#  '일단',
#  '시장',
#  '코트',
#  '버버리',
#  '트렌치',
#  '코트',
#  '버버리',
#  '셔츠',
#  '링크',
#  '비올',
#  '마스',
#  '야드',
#  '해당',
#  '생방송',
#  '컨텐츠',
#  '사용',
#  '기본',
#  '양식',
#  '아우',
#  '언타이틀',
#  '아이',
#  '상의',
#  '언타이틀',
#  '아이',
#  '하의',
#  '구제',
#  '신발',
#  '마스',
#  '야드',
#  '기타',
#  '몸무게',
#  '선택',
#  '구제',
#  '블루',
#  '쇼핑',
#  '후기',
#  '실사',
#  '사용',
#  '후기',
#  '누락',
#  '경우',
#  '참고',
#  '기본',
#  '양식',
#  '브랜드',
#  '품명',
#  '구제',
#  '빈티지',
#  '실사',
#  '이번',
#  '가을',
#  '구제',
#  '블루',
#  '공장',
#  '잠바',
#  '해도',
#  '구제',
#  '블루',
#  '사고',
#  '하자',
#  '발견',
#  '생로랑',
#  '구제',
#  '자켓',
#  '패션',
#  '이용',
#  '의무',
#  '링크',
#  '평이',
#  '택배',
#  '후기',
#  '무기명',
#  '투표',
#  '굿굿',
#  '결과',
#  '투표',
#  '투표',
#  '투표',
#  '확인',
#  '전체',
#  '투표',
#  '투표',
#  '확인',
#  '앤더슨',
#  '인사이드아웃',
#  '비엔나',
#  '토니',
#  '체크',
#  '패션',
#  '이용',
#  '의무',
#  '이번',
#  '할인',
#  '앤벨',
#  '인사이드아웃',
#  '레이저',
#  '무지',
#  '데리',
#  '뭔가',
#  '하나',
#  '무기명',
#  '투표',
#  '참여',
#  '인사이드아웃',
#  '비엔나',
#  '체크',
#  '닥치고',
#  '결과',
#  '투표',
#  '투표',
#  '투표',
#  '확인',
#  '전체',
#  '투표',
#  '투표',
#  '확인',
#  '동묘',
#  '구제',
#  '가죽',
#  '패션',
#  '이용',
#  '의무',
#  '예전',
#  '동묘',
#  '안주',
#  '가죽',
#  '자켓',
#  '현역',
#  '가능',
#  '한지',
#  '지금',
#  '해당',
#  '생방송',
#  '컨텐츠',
#  '사용',
#  '기본',
#  '양식',
#  '아우',
#  '구제',
#  '상의',
#  '신발',
#  '뉴발란스',
#  '슈펜',
#  '더비',
#  '기타',
#  '몸무게',
#  '선택',
#  '배진',
#  '동영상',
#  '팔로워',
#  '팔로잉',
#  '배진',
#  '동영상',
#  '문래',
#  '감성',
#  '해당',
#  '생방송',
#  '컨텐츠',
#  '사용',
#  '기본',
#  '양식',
#  '기본',
#  '양식',
#  '아우',
#  '구제',
#  '상의',
#  '샤카',
#  '웨어',
#  '하의',
#  '슬로우',
#  '신발',
#  '기타',
#  '몸무게',
#  '선택',
#  '스트릿',
#  '초보',
#  '룩입니',
#  '해당',
#  '생방송',
#  '컨텐츠',
#  '사용',
#  '기본',
#  '양식',
#  '기본',
#  '양식',
#  '아우',
#  '상의',
#  '구제',
#  '하의',
#  '신발',
#  '슈덩',
#  '기타',
#  '라이터',
#  '목걸이',
#  '가방',
#  '몸무게',
#  '선택',
#  '휴가',
#  '해당',
#  '생방송',
#  '컨텐츠',
#  '사용',
#  '기본',
#  '양식',
#  '여름',
#  '실내',
#  '최고',
#  '현대',
#  '서울',
#  '기본',
#  '양식',
#  '아우',
#  '상의',
#  '하의',
#  '일본',
#  '구제',
#  '신발',
#  '뉴발란스',
#  '토앤토',
#  '기타',
#  '모자',
#  ...]

# %%
word = dict(Counter(result).most_common(50))
word
# Out:
# {'구제': 492,
#  '기본': 675,
#  '기타': 528,
#  '나이키': 135,
#  '느낌': 39,
#  '다드': 54,
#  '닥터마틴': 37,
#  '데님': 36,
#  '동묘': 37,
#  '동영상': 188,
#  '링크': 115,
#  '몸무게': 471,
#  '무탠': 48,
#  '바지': 57,
#  '버스': 90,
#  '브랜드': 54,
#  '블랙': 47,
#  '빈티지': 52,
#  '사용': 366,
#  '사이즈': 44,
#  '상의': 575,
#  '생방송': 273,
#  '선택': 398,
#  '셔츠': 51,
#  '스타일': 48,
#  '신발': 632,
#  '아우': 613,
#  '양식': 666,
#  '오버': 48,
#  '유니클로': 42,
#  '의무': 90,
#  '이용': 93,
#  '자켓': 52,
#  '제제': 48,
#  '조던': 40,
#  '착용': 72,
#  '체험': 44,
#  '컨텐츠': 296,
#  '코디': 61,
#  '투표': 49,
#  '팔로워': 91,
#  '팔로잉': 91,
#  '패션': 105,
#  '포인트': 41,
#  '폴로': 68,
#  '피드백': 47,
#  '하의': 342,
#  '해당': 264,
#  '협찬': 59,
#  '후기': 53}

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
plt.rc('font', family='NanumBarunGothic') 

font='/content/NanumBarunGothic.ttf'

# %%
def color_func(word, font_size, position,orientation,random_state=None, **kwargs):
    return("hsl({:d},{:d}%, {:d}%)".format(np.random.randint(212,313),np.random.randint(26,32),np.random.randint(45,80)))

wc = WordCloud(font_path= font, background_color='white', width=1000, height=1000, color_func=color_func).generate(' '.join(word))
' '.join(word)
# Out:
# '기본 양식 신발 아우 상의 기타 구제 몸무게 선택 사용 하의 컨텐츠 생방송 해당 동영상 나이키 링크 패션 이용 팔로워 팔로잉 의무 버스 착용 폴로 코디 협찬 바지 다드 브랜드 후기 자켓 빈티지 셔츠 투표 무탠 스타일 오버 제제 블랙 피드백 체험 사이즈 유니클로 포인트 조던 느낌 동묘 닥터마틴 데님'

# %%
plt.imshow(wc)
plt.axis("off")
plt.show()
